# %%
import numpy as np

# %%
B = np.array([[3,1],
              [0,2]])

# %%
eigenvalues, eigenvectors=np.linalg.eig(B)

# %%
print('matirx B:')
print(B)
# Out:
# matirx B:
# [[3 1]
#  [0 2]]

# %%
print('matrix B')
print(eigenvalues)
# Out:
# matrix B
# [3. 2.]

# %%
print('/nEigenvectors (each column corresponds to an eigenvalues):')
print(eigenvectors)
# Out:
# /nEigenvectors (each column corresponds to an eigenvalues):
# [[ 1.         -0.70710678]
#  [ 0.          0.70710678]]
